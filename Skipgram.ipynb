# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import nltk
import random
from sklearn.model_selection import train_test_split
import time

# %%
class Skipgram1(object):
  def __init__(self, train_data, learning_rate, epochs, context, k, batch):
    # k is the dimension of embedding layer.
    # so, embedding has k*1 dimension

    # d is dimension of word vectors (one-hot) -> d*1
    self.eta = learning_rate
    self.context = context
    self.d = len(set(train_data))
    self.epochs = epochs
    self.m = len(train_data)
    self.k = k
    self.batch = batch


    self.weights = []
    self.weights.append(np.random.randn(self.d, k))
    self.weights.append(np.random.randn(k, self.d))

    self.d_weights = []
    self.d_weights.append(np.random.randn(self.d, k))
    self.d_weights.append(np.random.randn(k, self.d))

    self.one_hot(train_data, self.d)

    self.train(train_data)


  def one_hot(self, tokens, d):
    # tokens has the work tokens after preprocessing
    # tokens = ['I', 'love', 'game', 'football'] from 'I love the game of football'

    # d is the number of unique words in tokens
    # d -> dimension of word vectors

    self.word_loc = {}
    self.words = {}
    loc = 0

    for i in tokens:
      try:
        temp = self.word_loc[i]
      except KeyError:
        self.word_loc[i] = loc
        # self.word_loc[i][loc] = 1
        self.words[loc] = i
        # print(loc, i)
        loc += 1

      if loc == d:
        break


  def create_input(self, train_data, J):
    # train_data is 1*n where n is the number of words
    # context is the context size
    # output is a m*d matrix -> X_train

    self.X_train = []
    self.Y_train = []



    for j in range(J, J+self.batch):
      if(j >= self.m):
        break

      x = [0]*self.d
      y = [0]*self.d
      x[self.word_loc[train_data[j]]] = 1

      if(j < self.context):
        for i in range(j):
          y[self.word_loc[train_data[i]]] = 1
      else:
        for i in range(j-self.context, j):
          y[self.word_loc[train_data[i]]] = 1

      if(j> self.m-self.context-1):
        for i in range(j+1, self.m):
          y[self.word_loc[train_data[i]]] = 1
      else:
        for i in range(j+1, j+self.context+1):
          y[self.word_loc[train_data[i]]] = 1

      self.X_train.append(x)
      self.Y_train.append(y)

  def forward(self, x):
    # x -> 1*d matrix
    # weights[0] -> d*k matrix
    # embedding -> 1*k matrix
    # weights[1] -> k*d matrix
    # output_net -> 1*d matrix
    # pred -> softmax(output_net) -> 1*d matrix

    # m -> number of words in train set
    # d -> dimension of word vectors

    self.embedding = np.matmul(x, self.weights[0])
    self.output_net = np.matmul(self.embedding, self.weights[1])
    # self.pred = np.exp(self.output_net)/np.sum(np.exp(self.output_net))
    self.pred = np.exp(self.output_net - np.max(self.output_net))/ np.sum(np.exp(self.output_net - np.max(self.output_net)))
    self.pred = np.exp(self.output_net - np.max(self.output_net)) / np.sum(
            np.exp(self.output_net - np.max(self.output_net))
        )

  def backward(self, x, y):
    # loss -> m*d matrix


    self.loss = np.array(y) - self.pred
    #print(self.embedding.shape)
    # print(self.weights[1].T.shape)
    size=x.shape
    self.d_weights[1] = np.matmul(self.embedding.reshape(self.k, size[0]), self.loss.reshape(size[0], self.d))
    self.d_weights[0] = np.matmul(x.reshape(self.d, size[0]), np.matmul(self.loss, self.weights[1].T).reshape(size[0], self.k))

    self.weights[0] = self.weights[0] - self.eta*self.d_weights[0]
    self.weights[1] = self.weights[1] - self.eta*self.d_weights[1]


  def train(self, train_data):
    for i in range(self.epochs):
      loss = 0
      j = 0
      while(j < self.m):
        t0 = time.time()
        self.create_input(train_data, j)

        # print('Epoch: ', i, " Instance: ", j)

        t1 = time.time()
        self.forward(self.X_train)
        t2 = time.time()
        self.backward(np.array(self.X_train), np.array(self.Y_train))
        t3 = time.time()

        temp = 0
        # loss = -np.sum(self.Y_train * np.log(self.pred))

        j += self.batch
        t4 = time.time()

        print('epoch: ', i+1, ' batch: ', j, 'loss: ', np.sum(self.loss), 't0, t1, t2, t3: ', t1-t0, t2-t1, t3-t2, t4-t3, 'total time: ', t4-t0)


  def predict(self, s):
    vec = [0]*self.d
    vec[self.word_loc[s]] = 1
    self.forward(np.array(vec))

    p = list(self.pred)
    length_p = len(p)
    for i in range(2*self.context):
      max_val = max(p)
      loc = p.index(max_val)
      prob = max_val
      print("Predicted word is: ", self.words[loc], " with probability: ", prob)
      p[loc] = -1
    return self.pred

# %%
# train_data = "The earth revolves around the sun. The moon revolves around the earth"
# # # train_data = "situation power rather much way disposition think little well disadvantage threaten alloy many enjoyment danger however present unperceived mean rank misfortune sorrow come gentle sorrow shape disagreeable consciousness miss taylor married miss taylor loss first brought grief wedding day beloved friend emma first sat mournful thought continuance wedding bride people go father left dine together prospect third cheer long even father compose sleep dinner usual sit think lose event every promise happiness friend mr weston man unexceptionable character easy fortune suitable age pleasant manner satisfaction consider self deny generous friendship always wish promote match black morning work want miss taylor would felt every hour every day recall past kindness kindness affection sixteen year taught played five year old devote power attach amuse health nurse various illness childhood large debt gratitude owe intercourse last seven year equal footing perfect unreserve soon follow isabella marriage left yet dearer tenderer recollection friend companion possess intelligent well inform useful gentle know way family interested concern peculiarly interested every pleasure every scheme one could speak every thought arose affection could never find fault bear change true friend go half mile emma aware great must difference mr weston half mile miss taylor house advantage natural domestic great danger suffer intellectual solitude dearly love father companion could meet conversation rational playful evil actual disparity age mr woodhouse married early much increase constitution habit valetudinarian life without activity mind body much old man way year though everywhere beloved friendliness heart amiable temper talent could recommend time sister though comparatively little remove matrimony settle london sixteen mile much beyond daily reach many long october november even must struggle hartfield christmas brought next visit isabella husband little child fill house give pleasant society highbury large populous village almost amount town hartfield spite separate lawn shrubbery name really belong afford equal woodhouses first consequence look many acquaintance place father universally civil one among could accepted lieu miss taylor even half day melancholy change emma could sigh wish impossible thing till father awoke make necessary cheerful spirit require support nervous man easily depressed fond every body use hat part hat change every kind matrimony origin change always disagreeable mean yet reconcile daughter marry could ever speak compassion though entirely match affection oblige part miss taylor habit gentle selfishness never able suppose people could feel differently much dispose think miss taylor do sad thing would great deal happier spent rest life hartfield emma smile chat cheerfully could keep thought tea come impossible say exactly say dinner poor miss taylor wish pity mr weston ever thought agree papa know mr weston good humour pleasant excellent man thoroughly"
# train_data = train_data.split()

# %%
train_data = open('/content/Dataset_new.txt', 'r').read().split()
learning_rate = 0.03
epochs = 2
context = 5
k = 100
batch_size = 100

# %%
model = Skipgram1(train_data, learning_rate, epochs, context, k, batch_size)
# Out:
# epoch:  2  batch:  153900 loss:  988.0 t0, t1, t2, t3:  0.010722637176513672 0.26170945167541504 0.24701166152954102 1.5735626220703125e-05 total time:  0.5194594860076904
# epoch:  2  batch:  154000 loss:  996.0 t0, t1, t2, t3:  0.010476350784301758 0.28117895126342773 0.2497696876525879 2.6226043701171875e-06 total time:  0.5414276123046875
# epoch:  2  batch:  154100 loss:  114.0 t0, t1, t2, t3:  0.008376359939575195 0.042905330657958984 0.0783684253692627 4.0531158447265625e-06 total time:  0.1296541690826416

# %%
# test = "advantage natural domestic great danger suffer intellectual solitude dearly love father companion could meet conversation rational playful evil actual disparity"
test = "around"
# test = test.split()
model.predict(test)
# Out:
# Predicted word is:  strut  with probability:  1.0
# Predicted word is:  persuasion  with probability:  0.0
# Predicted word is:  jane  with probability:  0.0
# Predicted word is:  austen  with probability:  0.0
# Predicted word is:  chapter  with probability:  0.0
# Predicted word is:  sir  with probability:  0.0
# Predicted word is:  walter  with probability:  0.0
# Predicted word is:  elliot  with probability:  0.0
# Predicted word is:  kellynch  with probability:  0.0
# Predicted word is:  hall  with probability:  0.0
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
print(len(train_data))
# Out:
# 1033136

# %%
w = model.weights
w0 = w[0]
w1 = w[1]

import csv
file = open('skipgram_weights0.csv', 'w', newline='')
write = csv.writer(file)

for i in range(model.d):
  write.writerow(list(w0[i]))
file.close()

file = open('skipgram_weights1.csv', 'w', newline='')
write = csv.writer(file)

for i in range(model.k):
  write.writerow(list(w1[i]))
file.close()

# %%
def predict(s):
  data = []
  for i in s:
    vec = [0]*model.d
    if (i not in train_data):
      vec = [0.5]*model.d
      # print("No Information About The Word")
      data.append(np.array(vec))
    else:
      vec = [0]*model.d
      vec[model.word_loc[i]] = 1
      model.forward(np.array(vec))
      data.append(model.pred)

  pred = list(data[0] + data[1] - data[2])
  # print(pred)
  maximum = max(pred)
  loc = model.words[pred.index(maximum)]

  print("Predicted word is:", loc)
  return loc

# %%
valfile=open('Validation.txt','r')
contents=valfile.read().split()
print(contents)
i=0
c=0
while (i < len(contents)):
  print("pair: ", i+1)
  s=[contents[i],contents[i+1],contents[i+2]]
  word=predict(s)
  if word==contents[i+3]:
    c=c+1
  i=i+4
tw=len(contents)/4
print("Accuracy: ", (c/tw), "Total matched:", c, "out of: ", tw)
# Out:
# ['walk', 'walks', 'see', 'sees', 'walk', 'walks', 'shuffle', 'shuffles', 'walk', 'walks', 'sing', 'sings', 'walk', 'walks', 'sit', 'sits', 'walk', 'walks', 'slow', 'slows', 'walk', 'walks', 'speak', 'speaks', 'walk', 'walks', 'swim', 'swims', 'walk', 'walks', 'talk', 'talks', 'walk', 'walks', 'think', 'thinks', 'walk', 'walks', 'vanish', 'vanishes', 'work', 'works', 'write', 'writes', 'work', 'works', 'decrease', 'decreases', 'work', 'works', 'describe', 'describes', 'work', 'works', 'eat', 'eats', 'work', 'works', 'enhance', 'enhances', 'work', 'works', 'estimate', 'estimates', 'work', 'works', 'find', 'finds', 'work', 'works', 'generate', 'generates', 'think', 'thinks', 'say', 'says', 'think', 'thinks', 'scream', 'screams', 'think', 'thinks', 'search', 'searches', 'think', 'thinks', 'see', 'sees', 'think', 'thinks', 'shuffle', 'shuffles', 'think', 'thinks', 'sing', 'sings', 'think', 'thinks', 'sit', 'sits', 'think', 'thinks', 'slow', 'slows', 'think', 'thinks', 'speak', 'speaks', 'think', 'thinks', 'swim', 'swims', 'think', 'thinks', 'talk', 'talks', 'vanish', 'vanishes', 'walk', 'walks', 'vanish', 'vanishes', 'work', 'works', 'vanish', 'vanishes', 'write', 'writes', 'vanish', 'vanishes', 'decrease', 'decreases', 'vanish', 'vanishes', 'describe', 'describes', 'vanish', 'vanishes', 'eat', 'eats', 'sing', 'sings', 'enhance', 'enhances', 'sing', 'sings', 'estimate', 'estimates', 'sing', 'sings', 'find', 'finds', 'sing', 'sings', 'generate', 'generates', 'sing', 'sings', 'go', 'goes', 'sing', 'sings', 'implement', 'implements', 'sing', 'sings', 'increase', 'increases', 'sing', 'sings', 'listen', 'listens', 'sing', 'sings', 'play', 'plays', 'sing', 'sings', 'predict', 'predicts', 'sing', 'sings', 'provide', 'provides', 'sing', 'sings', 'say', 'says', 'sing', 'sings', 'scream', 'screams', 'sing', 'sings', 'search', 'searches', 'sing', 'sings', 'see', 'sees', 'sing', 'sings', 'shuffle', 'shuffles', 'sit', 'sits', 'slow', 'slows', 'sit', 'sits', 'speak', 'speaks', 'sit', 'sits', 'swim', 'swims', 'sit', 'sits', 'talk', 'talks', 'sit', 'sits', 'think', 'thinks', 'sit', 'sits', 'vanish', 'vanishes', 'sit', 'sits', 'walk', 'walks', 'sit', 'sits', 'work', 'works', 'sit', 'sits', 'write', 'writes', 'sit', 'sits', 'decrease', 'decreases', 'sit', 'sits', 'describe', 'describes', 'sit', 'sits', 'eat', 'eats', 'sit', 'sits', 'enhance', 'enhances', 'sit', 'sits', 'estimate', 'estimates', 'sit', 'sits', 'find', 'finds', 'sit', 'sits', 'generate', 'generates', 'sit', 'sits', 'go', 'goes', 'say', 'says', 'listen', 'listens', 'say', 'says', 'play', 'plays', 'say', 'says', 'predict', 'predicts', 'say', 'says', 'provide', 'provides', 'scream', 'screams', 'search', 'searches', 'scream', 'screams', 'see', 'sees', 'scream', 'screams', 'shuffle', 'shuffles', 'scream', 'screams', 'sing', 'sings', 'play', 'plays', 'generate', 'generates', 'play', 'plays', 'go', 'goes', 'play', 'plays', 'implement', 'implements', 'play', 'plays', 'increase', 'increases', 'play', 'plays', 'listen', 'listens', 'predict', 'predicts', 'provide', 'provides', 'predict', 'predicts', 'say', 'says', 'predict', 'predicts', 'scream', 'screams', 'predict', 'predicts', 'search', 'searches', 'machine', 'machines', 'goat', 'goats', 'machine', 'machines', 'hand', 'hands', 'machine', 'machines', 'horse', 'horses', 'machine', 'machines', 'lion', 'lions', 'mango', 'mangoes', 'man', 'men', 'mango', 'mangoes', 'melon', 'melons', 'mango', 'mangoes', 'monkey', 'monkeys', 'mango', 'mangoes', 'mouse', 'mice', 'mango', 'mangoes', 'onion', 'onions', 'man', 'men', 'finger', 'fingers', 'man', 'men', 'goat', 'goats', 'man', 'men', 'hand', 'hands', 'man', 'men', 'horse', 'horses', 'man', 'men', 'lion', 'lions', 'man', 'men', 'machine', 'machines', 'man', 'men', 'mango', 'mangoes', 'melon', 'melons', 'monkey', 'monkeys', 'melon', 'melons', 'mouse', 'mice', 'melon', 'melons', 'onion', 'onions', 'melon', 'melons', 'pear', 'pears', 'melon', 'melons', 'pig', 'pigs', 'hand', 'hands', 'elephant', 'elephants',  ...
# pair:  1
# Predicted word is: hypertext
# pair:  5
# Predicted word is: hypertext
# pair:  9
# Predicted word is: hypertext
# pair:  13
# Predicted word is: hypertext
# pair:  17
# Predicted word is: hypertext
# pair:  21
# Predicted word is: hypertext
# pair:  25
# Predicted word is: hypertext
# pair:  29
# Predicted word is: hypertext
# pair:  33
# Predicted word is: hypertext
# pair:  37
# Predicted word is: hypertext
# pair:  41
# Predicted word is: jetheth
# pair:  45
# Predicted word is: jetheth
# pair:  49
# Predicted word is: jetheth
# pair:  53
# Predicted word is: jetheth
# pair:  57
# Predicted word is: jetheth
# pair:  61
# Predicted word is: jetheth
# pair:  65
# Predicted word is: jetheth
# pair:  69
# Predicted word is: jetheth
# pair:  73
# Predicted word is: undo
# pair:  77
# Predicted word is: undo
# pair:  81
# Predicted word is: undo
# pair:  85
# Predicted word is: undo
# pair:  89
# Predicted word is: undo
# pair:  93
# Predicted word is: undo
# pair:  97
# Predicted word is: undo
# pair:  101
# Predicted word is: undo
# pair:  105
# Predicted word is: undo
# pair:  109
# Predicted word is: undo
# pair:  113
# Predicted word is: undo
# pair:  117
# Predicted word is: churn
# pair:  121
# Predicted word is: churn
# pair:  125
# Predicted word is: churn
# pair:  129
# Predicted word is: churn
# pair:  133
# Predicted word is: churn
# pair:  137
# Predicted word is: churn
# pair:  141
# Predicted word is: inextricable
# pair:  145
# Predicted word is: inextricable
# pair:  149
# Predicted word is: inextricable
# pair:  153
# Predicted word is: inextricable
# pair:  157
# Predicted word is: inextricable
# pair:  161
# Predicted word is: inextricable
# pair:  165
# Predicted word is: inextricable
# pair:  169
# Predicted word is: inextricable
# pair:  173
# Predicted word is: inextricable
# pair:  177
# Predicted word is: inextricable
# pair:  181
# Predicted word is: inextricable
# pair:  185
# Predicted word is: inextricable
# pair:  189
# Predicted word is: inextricable
# pair:  193
# Predicted word is: inextricable
# pair:  197
# Predicted word is: inextricable
# pair:  201
# Predicted word is: inextricable
# pair:  205
# Predicted word is: wanteth
# pair:  209
# Predicted word is: wanteth
# pair:  213
# Predicted word is: wanteth
# pair:  217
# Predicted word is: wanteth
# pair:  221
# Predicted word is: wanteth
# pair:  225
# Predicted word is: wanteth
# pair:  229
# Predicted word is: wanteth
# pair:  233
# Predicted word is: wanteth
# pair:  237
# Predicted word is: wanteth
# pair:  241
# Predicted word is: wanteth
# pair:  245
# Predicted word is: wanteth
# pair:  249
# Predicted word is: wanteth
# pair:  253
# Predicted word is: wanteth
# pair:  257
# Predicted word is: wanteth
# pair:  261
# Predicted word is: wanteth
# pair:  265
# Predicted word is: wanteth
# pair:  269
# Predicted word is: wanteth
# pair:  273
# Predicted word is: spurres
# pair:  277
# Predicted word is: spurres
# pair:  281
# Predicted word is: spurres
# pair:  285
# Predicted word is: spurres
# pair:  289
# Predicted word is: come
# pair:  293
# Predicted word is: come
# pair:  297
# Predicted word is: come
# pair:  301
# Predicted word is: come
# pair:  305
# Predicted word is: rome
# pair:  309
# Predicted word is: rome
# pair:  313
# Predicted word is: rome
# pair:  317
# Predicted word is: rome
# pair:  321
# Predicted word is: rome
# pair:  325
# Predicted word is: harod
# pair:  329
# Predicted word is: harod
# pair:  333
# Predicted word is: harod
# pair:  337
# Predicted word is: harod
# pair:  341
# Predicted word is: expedite
# pair:  345
# Predicted word is: expedite
# pair:  349
# Predicted word is: expedite
# pair:  353
# Predicted word is: expedite
# pair:  357
# Predicted word is: jane
# pair:  361
# Predicted word is: emma
# pair:  365
# Predicted word is: emma
# pair:  369
# Predicted word is: austen
# pair:  373
# Predicted word is: austen
# pair:  377
# Predicted word is: bullfrog
# pair:  381
# Predicted word is: bullfrog
# pair:  385
# Predicted word is: bullfrog
# pair:  389
# Predicted word is: bullfrog
# pair:  393
# Predicted word is: bullfrog
# pair:  397
# Predicted word is: bullfrog
# pair:  401
# Predicted word is: bullfrog
# pair:  405
# Predicted word is: contiguous
# pair:  409
# Predicted word is: contiguous
# pair:  413
# Predicted word is: contiguous
# pair:  417
# Predicted word is: contiguous
# pair:  421
# Predicted word is: contiguous
# pair:  425
# Predicted word is: raisin
# pair:  429
# Predicted word is: raisin
# pair:  433
# Predicted word is: raisin
# pair:  437
# Predicted word is: raisin
# pair:  441
# Predicted word is: dispeopled
# pair:  445
# Predicted word is: dispeopled
# pair:  449
# Predicted word is: dispeopled
# pair:  453
# Predicted word is: dispeopled
# pair:  457
# Predicted word is: asphyxiate
# pair:  461
# Predicted word is: asphyxiate
# pair:  465
# Predicted word is: asphyxiate
# pair:  469
# Predicted word is: asphyxiate
# pair:  473
# Predicted word is: hedgeless
# pair:  477
# Predicted word is: hedgeless
# pair:  481
# Predicted word is: hedgeless
# pair:  485
# Predicted word is: shomer
# pair:  489
# Predicted word is: shomer
# pair:  493
# Predicted word is: shomer
# pair:  497
# Predicted word is: shomer
# pair:  501
# Predicted word is: shomer
# pair:  505
# Predicted word is: ork
# pair:  509
# Predicted word is: ork
# pair:  513
# Predicted word is: ork
# pair:  517
# Predicted word is: ork
# pair:  521
# Predicted word is: ork
# pair:  525
# Predicted word is: sikoke
# pair:  529
# Predicted word is: sikoke
# pair:  533
# Predicted word is: sikoke
# pair:  537
# Predicted word is: sikoke
# pair:  541
# Predicted word is: sikoke
# pair:  545
# Predicted word is: jane
# pair:  549
# Predicted word is: emma
# pair:  553
# Predicted word is: emma
# pair:  557
# Predicted word is: emma
# pair:  561
# Predicted word is: emma
# pair:  565
# Predicted word is: emma
# pair:  569
# Predicted word is: emma
# pair:  573
# Predicted word is: emma
# pair:  577
# Predicted word is: emma
# pair:  581
# Predicted word is: emma
# pair:  585
# Predicted word is: emma
# pair:  589
# Predicted word is: deadliest
# pair:  593
# Predicted word is: deadliest
# pair:  597
# Predicted word is: deadliest
# pair:  601
# Predicted word is: deadliest
# pair:  605
# Predicted word is: deadliest
# pair:  609
# Predicted word is: deadliest
# pair:  613
# Predicted word is: deadliest
# pair:  617
# Predicted word is: lawfully
# pair:  621
# Predicted word is: lawfully
# pair:  625
# Predicted word is: lawfully
# pair:  629
# Predicted word is: lawfully
# pair:  633
# Predicted word is: emma
# pair:  637
# Predicted word is: emma
# pair:  641
# Predicted word is: gaspings
# pair:  645
# Predicted word is: gaspings
# pair:  649
# Predicted word is: gaspings
# pair:  653
# Predicted word is: frigid
# pair:  657
# Predicted word is: frigid
# pair:  661
# Predicted word is: frigid
# pair:  665
# Predicted word is: keystone
# pair:  669
# Predicted word is: keystone
# pair:  673
# Predicted word is: keystone
# pair:  677
# Predicted word is: keystone
# pair:  681
# Predicted word is: keystone
# pair:  685
# Predicted word is: keystone
# pair:  689
# Predicted word is: keystone
# pair:  693
# Predicted word is: emma
# pair:  697
# Predicted word is: emma
# pair:  701
# Predicted word is: emma
# pair:  705
# Predicted word is: shage
# pair:  709
# Predicted word is: shage
# pair:  713
# Predicted word is: shage
# pair:  717
# Predicted word is: shage
# pair:  721
# Predicted word is: shage
# pair:  725
# Predicted word is: shage
# pair:  729
# Predicted word is: quella
# pair:  733
# Predicted word is: quella
# pair:  737
# Predicted word is: quella
# pair:  741
# Predicted word is: quella
# pair:  745
# Predicted word is: emma
# pair:  749
# Predicted word is: jane
# pair:  753
# Predicted word is: emma
# pair:  757
# Predicted word is: emma
# pair:  761
# Predicted word is: emma
# pair:  765
# Predicted word is: emma
# pair:  769
# Predicted word is: emma
# pair:  773
# Predicted word is: emma
# pair:  777
# Predicted word is: emma
# pair:  781
# Predicted word is: emma
# pair:  785
# Predicted word is: emma
# pair:  789
# Predicted word is: emma
# pair:  793
# Predicted word is: emma
# pair:  797
# Predicted word is: pantomimic
# pair:  801
# Predicted word is: pantomimic
# pair:  805
# Predicted word is: pantomimic
# pair:  809
# Predicted word is: pantomimic
# pair:  813
# Predicted word is: emma
# pair:  817
# Predicted word is: emma
# pair:  821
# Predicted word is: emma
# pair:  825
# Predicted word is: emma
# pair:  829
# Predicted word is: jane
# pair:  833
# Predicted word is: emma
# pair:  837
# Predicted word is: emma
# pair:  841
# Predicted word is: emma
# pair:  845
# Predicted word is: emma
# pair:  849
# Predicted word is: emma
# pair:  853
# Predicted word is: emma
# pair:  857
# Predicted word is: emma
# pair:  861
# Predicted word is: emma
# pair:  865
# Predicted word is: emma
# pair:  869
# Predicted word is: vnspeake
# pair:  873
# Predicted word is: vnspeake
# pair:  877
# Predicted word is: vnspeake
# pair:  881
# Predicted word is: vnspeake
# pair:  885
# Predicted word is: vnspeake
# pair:  889
# Predicted word is: vnspeake
# pair:  893
# Predicted word is: vnspeake
# pair:  897
# Predicted word is: vnspeake
# pair:  901
# Predicted word is: vnspeake
# pair:  905
# Predicted word is: repartee
# pair:  909
# Predicted word is: repartee
# pair:  913
# Predicted word is: repartee
# pair:  917
# Predicted word is: repartee
# pair:  921
# Predicted word is: repartee
# pair:  925
# Predicted word is: repartee
# pair:  929
# Predicted word is: repartee
# pair:  933
# Predicted word is: repartee
# pair:  937
# Predicted word is: repartee
# pair:  941
# Predicted word is: repartee
# pair:  945
# Predicted word is: repartee
# pair:  949
# Predicted word is: repartee
# pair:  953
# Predicted word is: repartee
# pair:  957
# Predicted word is: repartee
# pair:  961
# Predicted word is: repartee
# pair:  965
# Predicted word is: repartee
# pair:  969
# Predicted word is: repartee
# pair:  973
# Predicted word is: repartee
# pair:  977
# Predicted word is: repartee
# pair:  981
# Predicted word is: repartee
# pair:  985
# Predicted word is: repartee
# pair:  989
# Predicted word is: repartee
# pair:  993
# Predicted word is: kingdom
# pair:  997
# Predicted word is: kingdom
# pair:  1001
# Predicted word is: kingdom
# pair:  1005
# Predicted word is: kingdom
# pair:  1009
# Predicted word is: kingdom
# pair:  1013
# Predicted word is: kingdom
# pair:  1017
# Predicted word is: kingdom
# pair:  1021
# Predicted word is: kingdom
# pair:  1025
# Predicted word is: kingdom
# pair:  1029
# Predicted word is: kingdom
# pair:  1033
# Predicted word is: kingdom
# pair:  1037
# Predicted word is: huguenot
# pair:  1041
# Predicted word is: huguenot
# pair:  1045
# Predicted word is: huguenot
# pair:  1049
# Predicted word is: huguenot
# pair:  1053
# Predicted word is: emma
# pair:  1057
# Predicted word is: emma
# pair:  1061
# Predicted word is: emma
# pair:  1065
# Predicted word is: emma
# pair:  1069
# Predicted word is: emma
# pair:  1073
# Predicted word is: emma
# pair:  1077
# Predicted word is: emma
# pair:  1081
# Predicted word is: emma
# pair:  1085
# Predicted word is: emma
# pair:  1089
# Predicted word is: emma
# pair:  1093
# Predicted word is: emma
# pair:  1097
# Predicted word is: jane
# pair:  1101
# Predicted word is: emma
# pair:  1105
# Predicted word is: emma
# pair:  1109
# Predicted word is: emma
# pair:  1113
# Predicted word is: emma
# pair:  1117
# Predicted word is: emma
# pair:  1121
# Predicted word is: jane
# pair:  1125
# Predicted word is: emma
# pair:  1129
# Predicted word is: emma
# pair:  1133
# Predicted word is: diadem
# pair:  1137
# Predicted word is: diadem
# pair:  1141
# Predicted word is: diadem
# pair:  1145
# Predicted word is: diadem
# pair:  1149
# Predicted word is: diadem
# pair:  1153
# Predicted word is: diadem
# pair:  1157
# Predicted word is: emma
# pair:  1161
# Predicted word is: emma
# pair:  1165
# Predicted word is: emma
# pair:  1169
# Predicted word is: emma
# pair:  1173
# Predicted word is: emma
# pair:  1177
# Predicted word is: jane
# pair:  1181
# Predicted word is: emma
# pair:  1185
# Predicted word is: emma
# pair:  1189
# Predicted word is: emma
# pair:  1193
# Predicted word is: emma
# pair:  1197
# Predicted word is: emma
# pair:  1201
# Predicted word is: emma
# pair:  1205
# Predicted word is: emma
# pair:  1209
# Predicted word is: emma
# pair:  1213
# Predicted word is: emma
# pair:  1217
# Predicted word is: emma
# pair:  1221
# Predicted word is: emma
# pair:  1225
# Predicted word is: harpoon
# pair:  1229
# Predicted word is: harpoon
# pair:  1233
# Predicted word is: harpoon
# pair:  1237
# Predicted word is: harpoon
# pair:  1241
# Predicted word is: harpoon
# pair:  1245
# Predicted word is: harpoon
# pair:  1249
# Predicted word is: harpoon
# pair:  1253
# Predicted word is: harpoon
# pair:  1257
# Predicted word is: harpoon
# pair:  1261
# Predicted word is: harpoon
# pair:  1265
# Predicted word is: harpoon
# pair:  1269
# Predicted word is: harpoon
# pair:  1273
# Predicted word is: harpoon
# pair:  1277
# Predicted word is: harpoon
# pair:  1281
# Predicted word is: harpoon
# pair:  1285
# Predicted word is: harpoon
# pair:  1289
# Predicted word is: harpoon
# pair:  1293
# Predicted word is: harpoon
# pair:  1297
# Predicted word is: harpoon
# pair:  1301
# Predicted word is: distinct
# pair:  1305
# Predicted word is: distinct
# pair:  1309
# Predicted word is: distinct
# pair:  1313
# Predicted word is: distinct
# pair:  1317
# Predicted word is: distinct
# pair:  1321
# Predicted word is: distinct
# pair:  1325
# Predicted word is: distinct
# pair:  1329
# Predicted word is: distinct
# pair:  1333
# Predicted word is: distinct
# pair:  1337
# Predicted word is: distinct
# pair:  1341
# Predicted word is: distinct
# pair:  1345
# Predicted word is: luff
# pair:  1349
# Predicted word is: luff
# pair:  1353
# Predicted word is: luff
# pair:  1357
# Predicted word is: luff
# pair:  1361
# Predicted word is: luff
# pair:  1365
# Predicted word is: luff
# pair:  1369
# Predicted word is: luff
# pair:  1373
# Predicted word is: luff
# pair:  1377
# Predicted word is: luff
# pair:  1381
# Predicted word is: luff
# pair:  1385
# Predicted word is: luff
# pair:  1389
# Predicted word is: luff
# pair:  1393
# Predicted word is: luff
# pair:  1397
# Predicted word is: luff
# pair:  1401
# Predicted word is: luff
# pair:  1405
# Predicted word is: emma
# pair:  1409
# Predicted word is: emma
# pair:  1413
# Predicted word is: jane
# pair:  1417
# Predicted word is: emma
# pair:  1421
# Predicted word is: progressive
# pair:  1425
# Predicted word is: progressive
# pair:  1429
# Predicted word is: progressive
# pair:  1433
# Predicted word is: progressive
# pair:  1437
# Predicted word is: progressive
# pair:  1441
# Predicted word is: progressive
# pair:  1445
# Predicted word is: progressive
# pair:  1449
# Predicted word is: progressive
# pair:  1453
# Predicted word is: progressive
# pair:  1457
# Predicted word is: progressive
# pair:  1461
# Predicted word is: progressive
# pair:  1465
# Predicted word is: progressive
# pair:  1469
# Predicted word is: progressive
# pair:  1473
# Predicted word is: progressive
# pair:  1477
# Predicted word is: progressive
# pair:  1481
# Predicted word is: progressive
# pair:  1485
# Predicted word is: invigoration
# pair:  1489
# Predicted word is: invigoration
# pair:  1493
# Predicted word is: invigoration
# pair:  1497
# Predicted word is: invigoration
# pair:  1501
# Predicted word is: invigoration
# pair:  1505
# Predicted word is: invigoration
# pair:  1509
# Predicted word is: invigoration
# pair:  1513
# Predicted word is: shimeon
# pair:  1517
# Predicted word is: shimeon
# pair:  1521
# Predicted word is: shimeon
# pair:  1525
# Predicted word is: shimeon
# pair:  1529
# Predicted word is: shimeon
# pair:  1533
# Predicted word is: shimeon
# pair:  1537
# Predicted word is: shimeon
# pair:  1541
# Predicted word is: shimeon
# pair:  1545
# Predicted word is: shimeon
# pair:  1549
# Predicted word is: shimeon
# pair:  1553
# Predicted word is: shimeon
# pair:  1557
# Predicted word is: ithmah
# pair:  1561
# Predicted word is: ithmah
# pair:  1565
# Predicted word is: ithmah
# pair:  1569
# Predicted word is: ithmah
# pair:  1573
# Predicted word is: ithmah
# pair:  1577
# Predicted word is: ithmah
# pair:  1581
# Predicted word is: ithmah
# pair:  1585
# Predicted word is: ithmah
# pair:  1589
# Predicted word is: ithmah
# pair:  1593
# Predicted word is: ithmah
# pair:  1597
# Predicted word is: ithmah
# pair:  1601
# Predicted word is: ithmah
# pair:  1605
# Predicted word is: adheres
# pair:  1609
# Predicted word is: adheres
# pair:  1613
# Predicted word is: adheres
# pair:  1617
# Predicted word is: adheres
# pair:  1621
# Predicted word is: adheres
# pair:  1625
# Predicted word is: adheres
# pair:  1629
# Predicted word is: adheres
# pair:  1633
# Predicted word is: adheres
# pair:  1637
# Predicted word is: adheres
# pair:  1641
# Predicted word is: adheres
# pair:  1645
# Predicted word is: emma
# pair:  1649
# Predicted word is: emma
# pair:  1653
# Predicted word is: emma
# pair:  1657
# Predicted word is: emma
# pair:  1661
# Predicted word is: jane
# pair:  1665
# Predicted word is: emma
# pair:  1669
# Predicted word is: emma
# pair:  1673
# Predicted word is: emma
# pair:  1677
# Predicted word is: emma
# pair:  1681
# Predicted word is: emma
# pair:  1685
# Predicted word is: emma
# pair:  1689
# Predicted word is: emma
# pair:  1693
# Predicted word is: emma
# pair:  1697
# Predicted word is: emma
# pair:  1701
# Predicted word is: emma
# pair:  1705
# Predicted word is: emma
# pair:  1709
# Predicted word is: emma
# pair:  1713
# Predicted word is: emma
# pair:  1717
# Predicted word is: emma
# pair:  1721
# Predicted word is: emma
# pair:  1725
# Predicted word is: emma
# pair:  1729
# Predicted word is: emma
# pair:  1733
# Predicted word is: emma
# pair:  1737
# Predicted word is: emma
# pair:  1741
# Predicted word is: emma
# pair:  1745
# Predicted word is: emma
# pair:  1749
# Predicted word is: emma
# pair:  1753
# Predicted word is: emma
# pair:  1757
# Predicted word is: emma
# pair:  1761
# Predicted word is: emma
# pair:  1765
# Predicted word is: emma
# pair:  1769
# Predicted word is: emma
# pair:  1773
# Predicted word is: peninsula
# pair:  1777
# Predicted word is: peninsula
# pair:  1781
# Predicted word is: peninsula
# pair:  1785
# Predicted word is: peninsula
# pair:  1789
# Predicted word is: peninsula
# pair:  1793
# Predicted word is: peninsula
# pair:  1797
# Predicted word is: peninsula
# pair:  1801
# Predicted word is: peninsula
# pair:  1805
# Predicted word is: peninsula
# pair:  1809
# Predicted word is: bunah
# pair:  1813
# Predicted word is: bunah
# pair:  1817
# Predicted word is: bunah
# pair:  1821
# Predicted word is: bunah
# pair:  1825
# Predicted word is: bunah
# pair:  1829
# Predicted word is: bunah
# pair:  1833
# Predicted word is: bunah
# pair:  1837
# Predicted word is: gehenna
# pair:  1841
# Predicted word is: gehenna
# pair:  1845
# Predicted word is: gehenna
# pair:  1849
# Predicted word is: gehenna
# pair:  1853
# Predicted word is: gehenna
# pair:  1857
# Predicted word is: gehenna
# pair:  1861
# Predicted word is: gehenna
# pair:  1865
# Predicted word is: gehenna
# pair:  1869
# Predicted word is: gehenna
# pair:  1873
# Predicted word is: gehenna
# pair:  1877
# Predicted word is: gehenna
# pair:  1881
# Predicted word is: gehenna
# pair:  1885
# Predicted word is: gehenna
# pair:  1889
# Predicted word is: gehenna
# pair:  1893
# Predicted word is: gehenna
# pair:  1897
# Predicted word is: quaff
# pair:  1901
# Predicted word is: quaff
# pair:  1905
# Predicted word is: quaff
# pair:  1909
# Predicted word is: quaff
# pair:  1913
# Predicted word is: quaff
# pair:  1917
# Predicted word is: quaff
# pair:  1921
# Predicted word is: quaff
# pair:  1925
# Predicted word is: quaff
# pair:  1929
# Predicted word is: kingdom
# pair:  1933
# Predicted word is: kingdom
# pair:  1937
# Predicted word is: kingdom
# pair:  1941
# Predicted word is: kingdom
# pair:  1945
# Predicted word is: kingdom
# pair:  1949
# Predicted word is: kingdom
# pair:  1953
# Predicted word is: kingdom
# pair:  1957
# Predicted word is: kingdom
# pair:  1961
# Predicted word is: kingdom
# pair:  1965
# Predicted word is: kingdom
# pair:  1969
# Predicted word is: come
# pair:  1973
# Predicted word is: come
# pair:  1977
# Predicted word is: come
# pair:  1981
# Predicted word is: come
# pair:  1985
# Predicted word is: come
# pair:  1989
# Predicted word is: come
# pair:  1993
# Predicted word is: come
# pair:  1997
# Predicted word is: come
# pair:  2001
# Predicted word is: come
# pair:  2005
# Predicted word is: come
# pair:  2009
# Predicted word is: rome
# pair:  2013
# Predicted word is: rome
# pair:  2017
# Predicted word is: rome
# pair:  2021
# Predicted word is: rome
# pair:  2025
# Predicted word is: rome
# pair:  2029
# Predicted word is: rome
# pair:  2033
# Predicted word is: rome
# pair:  2037
# Predicted word is: rome
# pair:  2041
# Predicted word is: rome
# pair:  2045
# Predicted word is: rome
# pair:  2049
# Predicted word is: rome
# pair:  2053
# Predicted word is: rome
# pair:  2057
# Predicted word is: rome
# pair:  2061
# Predicted word is: harod
# pair:  2065
# Predicted word is: harod
# pair:  2069
# Predicted word is: harod
# pair:  2073
# Predicted word is: harod
# pair:  2077
# Predicted word is: harod
# pair:  2081
# Predicted word is: harod
# pair:  2085
# Predicted word is: harod
# pair:  2089
# Predicted word is: harod
# pair:  2093
# Predicted word is: harod
# pair:  2097
# Predicted word is: harod
# pair:  2101
# Predicted word is: harod
# pair:  2105
# Predicted word is: harod
# pair:  2109
# Predicted word is: harod
# pair:  2113
# Predicted word is: harod
# pair:  2117
# Predicted word is: diner
# pair:  2121
# Predicted word is: diner
# pair:  2125
# Predicted word is: diner
# pair:  2129
# Predicted word is: diner
# pair:  2133
# Predicted word is: diner
# pair:  2137
# Predicted word is: diner
# pair:  2141
# Predicted word is: diner
# pair:  2145
# Predicted word is: diner
# pair:  2149
# Predicted word is: diner
# pair:  2153
# Predicted word is: diner
# pair:  2157
# Predicted word is: diner
# pair:  2161
# Predicted word is: diner
# pair:  2165
# Predicted word is: diner
# pair:  2169
# Predicted word is: diner
# pair:  2173
# Predicted word is: diner
# pair:  2177
# Predicted word is: diner
# pair:  2181
# Predicted word is: diner
# pair:  2185
# Predicted word is: pondereth
# pair:  2189
# Predicted word is: pondereth
# pair:  2193
# Predicted word is: pondereth
# pair:  2197
# Predicted word is: pondereth
# pair:  2201
# Predicted word is: pondereth
# pair:  2205
# Predicted word is: pondereth
# pair:  2209
# Predicted word is: nineteen
# pair:  2213
# Predicted word is: nineteen
# pair:  2217
# Predicted word is: nineteen
# pair:  2221
# Predicted word is: nineteen
# pair:  2225
# Predicted word is: nineteen
# pair:  2229
# Predicted word is: progressive
# pair:  2233
# Predicted word is: progressive
# pair:  2237
# Predicted word is: progressive
# pair:  2241
# Predicted word is: progressive
# pair:  2245
# Predicted word is: progressive
# pair:  2249
# Predicted word is: progressive
# pair:  2253
# Predicted word is: progressive
# pair:  2257
# Predicted word is: progressive
# pair:  2261
# Predicted word is: progressive
# pair:  2265
# Predicted word is: progressive
# pair:  2269
# Predicted word is: vaunt
# pair:  2273
# Predicted word is: vaunt
# pair:  2277
# Predicted word is: vaunt
# pair:  2281
# Predicted word is: vaunt
# pair:  2285
# Predicted word is: vaunt
# pair:  2289
# Predicted word is: altay
# pair:  2293
# Predicted word is: altay
# pair:  2297
# Predicted word is: altay
# pair:  2301
# Predicted word is: altay
# pair:  2305
# Predicted word is: altay
# pair:  2309
# Predicted word is: altay
# pair:  2313
# Predicted word is: altay
# pair:  2317
# Predicted word is: altay
# pair:  2321
# Predicted word is: altay
# pair:  2325
# Predicted word is: altay
# pair:  2329
# Predicted word is: servest
# pair:  2333
# Predicted word is: servest
# pair:  2337
# Predicted word is: servest
# pair:  2341
# Predicted word is: servest
# pair:  2345
# Predicted word is: servest
# pair:  2349
# Predicted word is: servest
# pair:  2353
# Predicted word is: servest
# pair:  2357
# Predicted word is: ramped
# pair:  2361
# Predicted word is: ramped
# pair:  2365
# Predicted word is: ramped
# pair:  2369
# Predicted word is: ramped
# pair:  2373
# Predicted word is: ramped
# pair:  2377
# Predicted word is: ramped
# pair:  2381
# Predicted word is: ramped
# pair:  2385
# Predicted word is: ramped
# pair:  2389
# Predicted word is: ramped
# pair:  2393
# Predicted word is: ramped
# pair:  2397
# Predicted word is: ramped
# pair:  2401
# Predicted word is: ramped
# pair:  2405
# Predicted word is: ramped
# pair:  2409
# Predicted word is: foyles
# pair:  2413
# Predicted word is: foyles
# pair:  2417
# Predicted word is: foyles
# pair:  2421
# Predicted word is: foyles
# pair:  2425
# Predicted word is: foyles
# pair:  2429
# Predicted word is: foyles
# pair:  2433
# Predicted word is: foyles
# pair:  2437
# Predicted word is: foyles
# pair:  2441
# Predicted word is: ruwenzori
# pair:  2445
# Predicted word is: ruwenzori
# pair:  2449
# Predicted word is: ruwenzori
# pair:  2453
# Predicted word is: ruwenzori
# pair:  2457
# Predicted word is: ruwenzori
# pair:  2461
# Predicted word is: ruwenzori
# pair:  2465
# Predicted word is: ruwenzori
# pair:  2469
# Predicted word is: ruwenzori
# pair:  2473
# Predicted word is: ruwenzori
# pair:  2477
# Predicted word is: breath
# pair:  2481
# Predicted word is: breath
# pair:  2485
# Predicted word is: breath
# pair:  2489
# Predicted word is: breath
# pair:  2493
# Predicted word is: breath
# pair:  2497
# Predicted word is: breath
# pair:  2501
# Predicted word is: breath
# pair:  2505
# Predicted word is: argent
# pair:  2509
# Predicted word is: argent
# pair:  2513
# Predicted word is: argent
# pair:  2517
# Predicted word is: argent
# pair:  2521
# Predicted word is: argent
# pair:  2525
# Predicted word is: argent
# pair:  2529
# Predicted word is: argent
# pair:  2533
# Predicted word is: argent
# pair:  2537
# Predicted word is: argent
# pair:  2541
# Predicted word is: argent
# pair:  2545
# Predicted word is: inner
# pair:  2549
# Predicted word is: inner
# pair:  2553
# Predicted word is: inner
# pair:  2557
# Predicted word is: inner
# pair:  2561
# Predicted word is: inner
# pair:  2565
# Predicted word is: inner
# pair:  2569
# Predicted word is: inner
# pair:  2573
# Predicted word is: renewer
# pair:  2577
# Predicted word is: renewer
# pair:  2581
# Predicted word is: renewer
# pair:  2585
# Predicted word is: renewer
# pair:  2589
# Predicted word is: renewer
# pair:  2593
# Predicted word is: renewer
# pair:  2597
# Predicted word is: renewer
# pair:  2601
# Predicted word is: renewer
# pair:  2605
# Predicted word is: renewer
# pair:  2609
# Predicted word is: renewer
# pair:  2613
# Predicted word is: renewer
# pair:  2617
# Predicted word is: renewer
# pair:  2621
# Predicted word is: irkutsk
# pair:  2625
# Predicted word is: irkutsk
# pair:  2629
# Predicted word is: irkutsk
# pair:  2633
# Predicted word is: lunar
# pair:  2637
# Predicted word is: lunar
# pair:  2641
# Predicted word is: lunar
# pair:  2645
# Predicted word is: lunar
# pair:  2649
# Predicted word is: lunar
# pair:  2653
# Predicted word is: lunar
# pair:  2657
# Predicted word is: lunar
# pair:  2661
# Predicted word is: lunar
# pair:  2665
# Predicted word is: lunar
# pair:  2669
# Predicted word is: absent
# pair:  2673
# Predicted word is: absent
# pair:  2677
# Predicted word is: absent
# pair:  2681
# Predicted word is: absent
# pair:  2685
# Predicted word is: absent
# pair:  2689
# Predicted word is: absent
# pair:  2693
# Predicted word is: absent
# pair:  2697
# Predicted word is: absent
# pair:  2701
# Predicted word is: softly
# pair:  2705
# Predicted word is: softly
# pair:  2709
# Predicted word is: softly
# pair:  2713
# Predicted word is: softly
# pair:  2717
# Predicted word is: softly
# pair:  2721
# Predicted word is: softly
# pair:  2725
# Predicted word is: softly
# pair:  2729
# Predicted word is: softly
# pair:  2733
# Predicted word is: softly
# pair:  2737
# Predicted word is: softly
# pair:  2741
# Predicted word is: softly
# pair:  2745
# Predicted word is: softly
# pair:  2749
# Predicted word is: anah
# pair:  2753
# Predicted word is: anah
# pair:  2757
# Predicted word is: anah
# pair:  2761
# Predicted word is: anah
# pair:  2765
# Predicted word is: anah
# pair:  2769
# Predicted word is: anah
# pair:  2773
# Predicted word is: anah
# pair:  2777
# Predicted word is: ditty
# pair:  2781
# Predicted word is: ditty
# pair:  2785
# Predicted word is: ditty
# pair:  2789
# Predicted word is: ditty
# pair:  2793
# Predicted word is: ditty
# pair:  2797
# Predicted word is: ditty
# pair:  2801
# Predicted word is: ditty
# pair:  2805
# Predicted word is: ditty
# pair:  2809
# Predicted word is: ditty
# pair:  2813
# Predicted word is: ditty
# pair:  2817
# Predicted word is: ditty
# pair:  2821
# Predicted word is: ditty
# pair:  2825
# Predicted word is: ditty
# pair:  2829
# Predicted word is: ditty
# pair:  2833
# Predicted word is: ditty
# pair:  2837
# Predicted word is: ditty
# pair:  2841
# Predicted word is: ear
# pair:  2845
# Predicted word is: ear
# pair:  2849
# Predicted word is: ear
# pair:  2853
# Predicted word is: ear
# pair:  2857
# Predicted word is: ear
# pair:  2861
# Predicted word is: ear
# pair:  2865
# Predicted word is: ear
# pair:  2869
# Predicted word is: altay
# pair:  2873
# Predicted word is: altay
# pair:  2877
# Predicted word is: altay
# pair:  2881
# Predicted word is: altay
# pair:  2885
# Predicted word is: altay
# pair:  2889
# Predicted word is: servest
# pair:  2893
# Predicted word is: servest
# pair:  2897
# Predicted word is: servest
# pair:  2901
# Predicted word is: servest
# pair:  2905
# Predicted word is: servest
# pair:  2909
# Predicted word is: servest
# pair:  2913
# Predicted word is: servest
# pair:  2917
# Predicted word is: inclos
# pair:  2921
# Predicted word is: inclos
# pair:  2925
# Predicted word is: inclos
# pair:  2929
# Predicted word is: inclos
# pair:  2933
# Predicted word is: inclos
# pair:  2937
# Predicted word is: inclos
# pair:  2941
# Predicted word is: inclos
# pair:  2945
# Predicted word is: inclos
# pair:  2949
# Predicted word is: inclos
# pair:  2953
# Predicted word is: inclos
# pair:  2957
# Predicted word is: inclos
# pair:  2961
# Predicted word is: ramped
# pair:  2965
# Predicted word is: ramped
# pair:  2969
# Predicted word is: ramped
# pair:  2973
# Predicted word is: ramped
# pair:  2977
# Predicted word is: ramped
# pair:  2981
# Predicted word is: ramped
# pair:  2985
# Predicted word is: ramped
# pair:  2989
# Predicted word is: ramped
# pair:  2993
# Predicted word is: disservice
# pair:  2997
# Predicted word is: disservice
# pair:  3001
# Predicted word is: disservice
# pair:  3005
# Predicted word is: disservice
# pair:  3009
# Predicted word is: disservice
# pair:  3013
# Predicted word is: disservice
# pair:  3017
# Predicted word is: disservice
# pair:  3021
# Predicted word is: mesopotamian
# pair:  3025
# Predicted word is: mesopotamian
# pair:  3029
# Predicted word is: mesopotamian
# pair:  3033
# Predicted word is: mesopotamian
# pair:  3037
# Predicted word is: mesopotamian
# pair:  3041
# Predicted word is: mesopotamian
# pair:  3045
# Predicted word is: mesopotamian
# pair:  3049
# Predicted word is: mesopotamian
# pair:  3053
# Predicted word is: mesopotamian
# pair:  3057
# Predicted word is: carlacue
# pair:  3061
# Predicted word is: carlacue
# pair:  3065
# Predicted word is: carlacue
# pair:  3069
# Predicted word is: carlacue
# pair:  3073
# Predicted word is: buffalo
# pair:  3077
# Predicted word is: buffalo
# pair:  3081
# Predicted word is: buffalo
# pair:  3085
# Predicted word is: buffalo
# pair:  3089
# Predicted word is: buffalo
# pair:  3093
# Predicted word is: buffalo
# pair:  3097
# Predicted word is: buffalo
# pair:  3101
# Predicted word is: sich
# pair:  3105
# Predicted word is: sich
# pair:  3109
# Predicted word is: sich
# pair:  3113
# Predicted word is: sich
# pair:  3117
# Predicted word is: sich
# pair:  3121
# Predicted word is: sich
# pair:  3125
# Predicted word is: sich
# pair:  3129
# Predicted word is: sich
# pair:  3133
# Predicted word is: midwinter
# pair:  3137
# Predicted word is: midwinter
# pair:  3141
# Predicted word is: midwinter
# pair:  3145
# Predicted word is: midwinter
# pair:  3149
# Predicted word is: midwinter
# pair:  3153
# Predicted word is: midwinter
# pair:  3157
# Predicted word is: midwinter
# pair:  3161
# Predicted word is: perseuer
# pair:  3165
# Predicted word is: perseuer
# pair:  3169
# Predicted word is: perseuer
# pair:  3173
# Predicted word is: perseuer
# pair:  3177
# Predicted word is: perseuer
# pair:  3181
# Predicted word is: perseuer
# pair:  3185
# Predicted word is: perseuer
# pair:  3189
# Predicted word is: perseuer
# pair:  3193
# Predicted word is: perseuer
# pair:  3197
# Predicted word is: perseuer
# pair:  3201
# Predicted word is: perseuer
# pair:  3205
# Predicted word is: perseuer
# pair:  3209
# Predicted word is: perseuer
# pair:  3213
# Predicted word is: perseuer
# pair:  3217
# Predicted word is: perseuer
# pair:  3221
# Predicted word is: perseuer
# pair:  3225
# Predicted word is: perseuer
# pair:  3229
# Predicted word is: perseuer
# pair:  3233
# Predicted word is: perseuer
# pair:  3237
# Predicted word is: proteus
# pair:  3241
# Predicted word is: proteus
# pair:  3245
# Predicted word is: proteus
# pair:  3249
# Predicted word is: proteus
# pair:  3253
# Predicted word is: proteus
# pair:  3257
# Predicted word is: proteus
# pair:  3261
# Predicted word is: grac
# pair:  3265
# Predicted word is: grac
# pair:  3269
# Predicted word is: grac
# pair:  3273
# Predicted word is: grac
# pair:  3277
# Predicted word is: grac
# pair:  3281
# Predicted word is: grac
# pair:  3285
# Predicted word is: grac
# pair:  3289
# Predicted word is: grac
# pair:  3293
# Predicted word is: grac
# pair:  3297
# Predicted word is: grac
# pair:  3301
# Predicted word is: grac
# pair:  3305
# Predicted word is: whoso
# pair:  3309
# Predicted word is: whoso
# pair:  3313
# Predicted word is: whoso
# pair:  3317
# Predicted word is: whoso
# pair:  3321
# Predicted word is: gavest
# pair:  3325
# Predicted word is: gavest
# pair:  3329
# Predicted word is: gavest
# pair:  3333
# Predicted word is: gavest
# pair:  3337
# Predicted word is: gavest
# pair:  3341
# Predicted word is: gavest
# pair:  3345
# Predicted word is: gavest
# pair:  3349
# Predicted word is: gavest
# pair:  3353
# Predicted word is: gavest
# pair:  3357
# Predicted word is: gavest
# pair:  3361
# Predicted word is: gavest
# pair:  3365
# Predicted word is: gavest
# pair:  3369
# Predicted word is: seyt
# pair:  3373
# Predicted word is: seyt
# pair:  3377
# Predicted word is: seyt
# pair:  3381
# Predicted word is: seyt
# pair:  3385
# Predicted word is: seyt
# pair:  3389
# Predicted word is: seyt
# pair:  3393
# Predicted word is: seyt
# pair:  3397
# Predicted word is: seyt
# pair:  3401
# Predicted word is: enthusiastically
# pair:  3405
# Predicted word is: enthusiastically
# pair:  3409
# Predicted word is: enthusiastically
# pair:  3413
# Predicted word is: enthusiastically
# pair:  3417
# Predicted word is: enthusiastically
# pair:  3421
# Predicted word is: enthusiastically
# pair:  3425
# Predicted word is: enthusiastically
# pair:  3429
# Predicted word is: enthusiastically
# pair:  3433
# Predicted word is: disinterestedness
# pair:  3437
# Predicted word is: disinterestedness
# pair:  3441
# Predicted word is: disinterestedness
# pair:  3445
# Predicted word is: disinterestedness
# pair:  3449
# Predicted word is: disinterestedness
# pair:  3453
# Predicted word is: disinterestedness
# pair:  3457
# Predicted word is: disinterestedness
# pair:  3461
# Predicted word is: disinterestedness
# pair:  3465
# Predicted word is: disinterestedness
# pair:  3469
# Predicted word is: disinterestedness
# pair:  3473
# Predicted word is: disinterestedness
# pair:  3477
# Predicted word is: parish
# pair:  3481
# Predicted word is: parish
# pair:  3485
# Predicted word is: parish
# pair:  3489
# Predicted word is: parish
# pair:  3493
# Predicted word is: parish
# pair:  3497
# Predicted word is: parish
# pair:  3501
# Predicted word is: parish
# pair:  3505
# Predicted word is: parish
# pair:  3509
# Predicted word is: resists
# pair:  3513
# Predicted word is: resists
# pair:  3517
# Predicted word is: resists
# pair:  3521
# Predicted word is: resists
# pair:  3525
# Predicted word is: resists
# pair:  3529
# Predicted word is: resists
# pair:  3533
# Predicted word is: resists
# pair:  3537
# Predicted word is: resists
# pair:  3541
# Predicted word is: resists
# pair:  3545
# Predicted word is: resists
# pair:  3549
# Predicted word is: resists
# pair:  3553
# Predicted word is: emma
# pair:  3557
# Predicted word is: emma
# pair:  3561
# Predicted word is: emma
# pair:  3565
# Predicted word is: emma
# pair:  3569
# Predicted word is: emma
# pair:  3573
# Predicted word is: emma
# pair:  3577
# Predicted word is: emma
# pair:  3581
# Predicted word is: emma
# pair:  3585
# Predicted word is: emma
# pair:  3589
# Predicted word is: emma
# pair:  3593
# Predicted word is: emma
# pair:  3597
# Predicted word is: emma
# pair:  3601
# Predicted word is: emma
# pair:  3605
# Predicted word is: emma
# pair:  3609
# Predicted word is: emma
# pair:  3613
# Predicted word is: emma
# pair:  3617
# Predicted word is: emma
# pair:  3621
# Predicted word is: emma
# pair:  3625
# Predicted word is: emma
# pair:  3629
# Predicted word is: emma
# pair:  3633
# Predicted word is: controller
# pair:  3637
# Predicted word is: controller
# pair:  3641
# Predicted word is: controller
# pair:  3645
# Predicted word is: controller
# pair:  3649
# Predicted word is: controller
# pair:  3653
# Predicted word is: controller
# pair:  3657
# Predicted word is: emma
# pair:  3661
# Predicted word is: austen
# pair:  3665
# Predicted word is: emma
# pair:  3669
# Predicted word is: emma
# pair:  3673
# Predicted word is: emma
# pair:  3677
# Predicted word is: emma
# pair:  3681
# Predicted word is: jane
# pair:  3685
# Predicted word is: emma
# pair:  3689
# Predicted word is: emma
# pair:  3693
# Predicted word is: emma
# pair:  3697
# Predicted word is: emma
# pair:  3701
# Predicted word is: emma
# pair:  3705
# Predicted word is: lute
# pair:  3709
# Predicted word is: lute
# pair:  3713
# Predicted word is: lute
# pair:  3717
# Predicted word is: lute
# pair:  3721
# Predicted word is: lute
# pair:  3725
# Predicted word is: lute
# pair:  3729
# Predicted word is: lute
# pair:  3733
# Predicted word is: lute
# pair:  3737
# Predicted word is: lute
# pair:  3741
# Predicted word is: bullfrog
# pair:  3745
# Predicted word is: bullfrog
# pair:  3749
# Predicted word is: bullfrog
# pair:  3753
# Predicted word is: bullfrog
# pair:  3757
# Predicted word is: bullfrog
# pair:  3761
# Predicted word is: bullfrog
# pair:  3765
# Predicted word is: bullfrog
# pair:  3769
# Predicted word is: bullfrog
# pair:  3773
# Predicted word is: bullfrog
# pair:  3777
# Predicted word is: bullfrog
# pair:  3781
# Predicted word is: bullfrog
# pair:  3785
# Predicted word is: bullfrog
# pair:  3789
# Predicted word is: emma
# pair:  3793
# Predicted word is: emma
# pair:  3797
# Predicted word is: emma
# pair:  3801
# Predicted word is: emma
# pair:  3805
# Predicted word is: emma
# pair:  3809
# Predicted word is: mourner
# pair:  3813
# Predicted word is: mourner
# pair:  3817
# Predicted word is: mourner
# pair:  3821
# Predicted word is: mourner
# pair:  3825
# Predicted word is: mourner
# pair:  3829
# Predicted word is: mourner
# pair:  3833
# Predicted word is: mourner
# pair:  3837
# Predicted word is: mourner
# pair:  3841
# Predicted word is: rufus
# pair:  3845
# Predicted word is: rufus
# pair:  3849
# Predicted word is: rufus
# pair:  3853
# Predicted word is: rufus
# pair:  3857
# Predicted word is: rizpah
# pair:  3861
# Predicted word is: rizpah
# pair:  3865
# Predicted word is: rizpah
# pair:  3869
# Predicted word is: rizpah
# pair:  3873
# Predicted word is: rizpah
# pair:  3877
# Predicted word is: rizpah
# pair:  3881
# Predicted word is: emma
# pair:  3885
# Predicted word is: emma
# pair:  3889
# Predicted word is: emma
# pair:  3893
# Predicted word is: emma
# pair:  3897
# Predicted word is: emma
# pair:  3901
# Predicted word is: emma
# pair:  3905
# Predicted word is: emma
# pair:  3909
# Predicted word is: emma
# pair:  3913
# Predicted word is: emma
# pair:  3917
# Predicted word is: emma
# pair:  3921
# Predicted word is: emma
# pair:  3925
# Predicted word is: emma
# pair:  3929
# Predicted word is: emma
# pair:  3933
# Predicted word is: emma
# pair:  3937
# Predicted word is: emma
# pair:  3941
# Predicted word is: emma
# pair:  3945
# Predicted word is: emma
# pair:  3949
# Predicted word is: emma
# pair:  3953
# Predicted word is: emma
# pair:  3957
# Predicted word is: ascanse
# pair:  3961
# Predicted word is: ascanse
# Accuracy:  0.0 Total matched: 0 out of:  991.0

# %%
s=["king","queen","man"]
predict(s)
# Out:
# Predicted word is: strut
# 'strut'
